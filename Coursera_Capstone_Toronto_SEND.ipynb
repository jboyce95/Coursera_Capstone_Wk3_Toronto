# %% [markdown]
# # Coursera Capstone - Toronto Segmentation and Clustering

# %% [markdown]
# ## Overview

# %% [markdown]
# This notebook attempts to pull PostalCode, Borough and Neighborhood from Toronto Wiki page. Below is a brief outline of useful resources and brief takeaways after completing this Assignment (for my future reference and others):
#
# * Portions of the Python for Data Science labs were helpful in the webscraping portion of this assignment.
# * Utlimately, I decided to use the Pandas tools (rather than BeautifulSoup) since our main objective was to extract tables from the target URL.
# * Stackoverflow.com was a great resource for getting through some sticking points (especially as it relates to pandas dataframes).
# * Pandas cheat sheets helped as quick reference reminders for methods to summarize data and its structure (here's an example of one of the few that I used https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)
# * The most challenging portion of this Assignment (at least for me) was flattening the groupby results in the Neighborhood column of the dataframe. The following website helped get me over the "hump" in that regard
# (http://queirozf.com/entries/pandas-dataframe-groupby-examples#flatten-hierarchical-indices-created-by-groupby). ...credit where credit is due.
# * Thank you for reviewing my notebook, and good luck on your endeavors!

# %% [markdown]
# ## Start off by importing libraries

# %%
# !pip install bs4 
# !pip install lxml
import numpy as np
import pandas as pd
import requests
import urllib.request, urllib.parse, urllib.error

from bs4 import BeautifulSoup #can use BeautifulSoup to parse website
# Out:
# Requirement already satisfied: bs4 in c:\users\jboyce\appdata\local\continuum\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\jboyce\appdata\local\continuum\anaconda3\lib\site-packages (from bs4) (4.6.3)
# You are using pip version 19.0, however version 19.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Requirement already satisfied: lxml in c:\users\jboyce\appdata\local\continuum\anaconda3\lib\site-packages (4.2.5)
# You are using pip version 19.0, however version 19.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# ## Use Pandas and its features to read the target URL

# %%
#web scraping using pandas
#note: set header = 0 to use the first row as column headers

d = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M', header=0)

#Interesting notes about the pandas list of tables that's created from reading the URL
#type(d) #prints 'list'
#print(len(d)) #prints '3' since there are 3 tables on this page. the one we want to use is index=0
#print(d[0]) #
#format of df['column_name']['row_#_in_column_name']

# %% [markdown]
# ### Extract the table from the URL as a Pandas dataframe (note the shape and column names)

# %%
#set the target table to a 'dataframe'
df = d[0]

#check the shape of df
print(len(df)) #prints '289' is the # of rows (including the column name row)
print(df.shape) #prints '(289, 3)'
print(df.columns) #prints 'Index(['Postcode', 'Borough', 'Neighbourhood'], dtype='object')'
# Out:
# 288
# (288, 3)
# Index(['Postcode', 'Borough', 'Neighbourhood'], dtype='object')

# %% [markdown]
# ### View the dataframe contents (use .head() if you only want to take a peek)

# %%
#view the df
print(df)
# Out:
#     Postcode           Borough  \
# 0        M1A      Not assigned
# 1        M2A      Not assigned
# 2        M3A        North York
# 3        M4A        North York
# 4        M5A  Downtown Toronto
# 5        M5A  Downtown Toronto
# 6        M6A        North York
# 7        M6A        North York
# 8        M7A      Queen's Park
# 9        M8A      Not assigned
# 10       M9A         Etobicoke
# 11       M1B       Scarborough
# 12       M1B       Scarborough
# 13       M2B      Not assigned
# 14       M3B        North York
# 15       M4B         East York
# 16       M4B         East York
# 17       M5B  Downtown Toronto
# 18       M5B  Downtown Toronto
# 19       M6B        North York
# 20       M7B      Not assigned
# 21       M8B      Not assigned
# 22       M9B         Etobicoke
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M1C       Scarborough
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# ..       ...               ...
# 258      M9X      Not assigned
# 259      M1Y      Not assigned
# 260      M2Y      Not assigned
# 261      M3Y      Not assigned
# 262      M4Y  Downtown Toronto
# 263      M5Y      Not assigned
# 264      M6Y      Not assigned
# 265      M7Y      East Toronto
# 266      M8Y         Etobicoke
# 267      M8Y         Etobicoke
# 268      M8Y         Etobicoke
# 269      M8Y         Etobicoke
# 270      M8Y         Etobicoke
# 271      M8Y         Etobicoke
# 272      M8Y         Etobicoke
# 273      M8Y         Etobicoke
# 274      M9Y      Not assigned
# 275      M1Z      Not assigned
# 276      M2Z      Not assigned
# 277      M3Z      Not assigned
# 278      M4Z      Not assigned
# 279      M5Z      Not assigned
# 280      M6Z      Not assigned
# 281      M7Z      Not assigned
# 282      M8Z         Etobicoke
# 283      M8Z         Etobicoke
# 284      M8Z         Etobicoke
# 285      M8Z         Etobicoke
# 286      M8Z         Etobicoke
# 287      M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                                         Harbourfront
# 5                                          Regent Park
# 6                                     Lawrence Heights
# 7                                       Lawrence Manor
# 8                                         Not assigned
# 9                                         Not assigned
# 10                                    Islington Avenue
# 11                                               Rouge
# 12                                             Malvern
# 13                                        Not assigned
# 14                                     Don Mills North
# 15                                    Woodbine Gardens
# 16                                       Parkview Hill
# 17                                             Ryerson
# 18                                     Garden District
# 19                                           Glencairn
# 20                                        Not assigned
# 21                                        Not assigned
# 22                                          Cloverdale
# 23                                           Islington
# 24                                        Martin Grove
# 25                                    Princess Gardens
# 26                                     West Deane Park
# 27                                      Highland Creek
# 28                                          Rouge Hill
# 29                                          Port Union
# ..                                                 ...
# 258                                       Not assigned
# 259                                       Not assigned
# 260                                       Not assigned
# 261                                       Not assigned
# 262                               Church and Wellesley
# 263                                       Not assigned
# 264                                       Not assigned
# 265  Business Reply Mail Processing Centre 969 Eastern
# 266                                         Humber Bay
# 267                                   King's Mill Park
# 268                           Kingsway Park South East
# 269                                          Mimico NE
# 270                                     Old Mill South
# 271                                 The Queensway East
# 272                              Royal York South East
# 273                                           Sunnylea
# 274                                       Not assigned
# 275                                       Not assigned
# 276                                       Not assigned
# 277                                       Not assigned
# 278                                       Not assigned
# 279                                       Not assigned
# 280                                       Not assigned
# 281                                       Not assigned
# 282                           Kingsway Park South West
# 283                                          Mimico NW
# 284                                 The Queensway West
# 285                              Royal York South West
# 286                                     South of Bloor
# 287                                       Not assigned
#
# [288 rows x 3 columns]

# %% [markdown]
# ### Check to see how many Boroughs are 'Not assigned'

# %%
#filter for Boroughs that are "Not Assigned"
df[df.Borough == 'Not assigned'] #shows df filtering rows with Borough == 'Not assigned'
# Out:
#     Postcode       Borough Neighbourhood
# 0        M1A  Not assigned  Not assigned
# 1        M2A  Not assigned  Not assigned
# 9        M8A  Not assigned  Not assigned
# 13       M2B  Not assigned  Not assigned
# 20       M7B  Not assigned  Not assigned
# 21       M8B  Not assigned  Not assigned
# 30       M2C  Not assigned  Not assigned
# 36       M7C  Not assigned  Not assigned
# 37       M8C  Not assigned  Not assigned
# 45       M2E  Not assigned  Not assigned
# 46       M3E  Not assigned  Not assigned
# 50       M7E  Not assigned  Not assigned
# 51       M8E  Not assigned  Not assigned
# 52       M9E  Not assigned  Not assigned
# 54       M2G  Not assigned  Not assigned
# 55       M3G  Not assigned  Not assigned
# 59       M7G  Not assigned  Not assigned
# 60       M8G  Not assigned  Not assigned
# 61       M9G  Not assigned  Not assigned
# 73       M7H  Not assigned  Not assigned
# 74       M8H  Not assigned  Not assigned
# 75       M9H  Not assigned  Not assigned
# 88       M7J  Not assigned  Not assigned
# 89       M8J  Not assigned  Not assigned
# 90       M9J  Not assigned  Not assigned
# 104      M7K  Not assigned  Not assigned
# 105      M8K  Not assigned  Not assigned
# 106      M9K  Not assigned  Not assigned
# 120      M7L  Not assigned  Not assigned
# 121      M8L  Not assigned  Not assigned
# ..       ...           ...           ...
# 202      M7T  Not assigned  Not assigned
# 203      M8T  Not assigned  Not assigned
# 204      M9T  Not assigned  Not assigned
# 209      M2V  Not assigned  Not assigned
# 210      M3V  Not assigned  Not assigned
# 223      M6V  Not assigned  Not assigned
# 224      M7V  Not assigned  Not assigned
# 237      M2W  Not assigned  Not assigned
# 238      M3W  Not assigned  Not assigned
# 241      M6W  Not assigned  Not assigned
# 242      M7W  Not assigned  Not assigned
# 247      M2X  Not assigned  Not assigned
# 248      M3X  Not assigned  Not assigned
# 253      M6X  Not assigned  Not assigned
# 254      M7X  Not assigned  Not assigned
# 258      M9X  Not assigned  Not assigned
# 259      M1Y  Not assigned  Not assigned
# 260      M2Y  Not assigned  Not assigned
# 261      M3Y  Not assigned  Not assigned
# 263      M5Y  Not assigned  Not assigned
# 264      M6Y  Not assigned  Not assigned
# 274      M9Y  Not assigned  Not assigned
# 275      M1Z  Not assigned  Not assigned
# 276      M2Z  Not assigned  Not assigned
# 277      M3Z  Not assigned  Not assigned
# 278      M4Z  Not assigned  Not assigned
# 279      M5Z  Not assigned  Not assigned
# 280      M6Z  Not assigned  Not assigned
# 281      M7Z  Not assigned  Not assigned
# 287      M9Z  Not assigned  Not assigned
#
# [77 rows x 3 columns]

# %% [markdown]
# ### Remove rows in the Borough column that are 'Not assigned' (and view the results)

# %%
#remove Postcodes that are "Not Assigned"
#df = df.drop(df[df.score < 50].index)
df_del_na = df.drop(df[df.Borough == 'Not assigned'].index)
df_del_na
# Out:
#     Postcode           Borough  \
# 2        M3A        North York
# 3        M4A        North York
# 4        M5A  Downtown Toronto
# 5        M5A  Downtown Toronto
# 6        M6A        North York
# 7        M6A        North York
# 8        M7A      Queen's Park
# 10       M9A         Etobicoke
# 11       M1B       Scarborough
# 12       M1B       Scarborough
# 14       M3B        North York
# 15       M4B         East York
# 16       M4B         East York
# 17       M5B  Downtown Toronto
# 18       M5B  Downtown Toronto
# 19       M6B        North York
# 22       M9B         Etobicoke
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M1C       Scarborough
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# 31       M3C        North York
# 32       M3C        North York
# 33       M4C         East York
# 34       M5C  Downtown Toronto
# 35       M6C              York
# 38       M9C         Etobicoke
# ..       ...               ...
# 235      M9V         Etobicoke
# 236      M1W       Scarborough
# 239      M4W  Downtown Toronto
# 240      M5W  Downtown Toronto
# 243      M8W         Etobicoke
# 244      M8W         Etobicoke
# 245      M9W         Etobicoke
# 246      M1X       Scarborough
# 249      M4X  Downtown Toronto
# 250      M4X  Downtown Toronto
# 251      M5X  Downtown Toronto
# 252      M5X  Downtown Toronto
# 255      M8X         Etobicoke
# 256      M8X         Etobicoke
# 257      M8X         Etobicoke
# 262      M4Y  Downtown Toronto
# 265      M7Y      East Toronto
# 266      M8Y         Etobicoke
# 267      M8Y         Etobicoke
# 268      M8Y         Etobicoke
# 269      M8Y         Etobicoke
# 270      M8Y         Etobicoke
# 271      M8Y         Etobicoke
# 272      M8Y         Etobicoke
# 273      M8Y         Etobicoke
# 282      M8Z         Etobicoke
# 283      M8Z         Etobicoke
# 284      M8Z         Etobicoke
# 285      M8Z         Etobicoke
# 286      M8Z         Etobicoke
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                                         Harbourfront
# 5                                          Regent Park
# 6                                     Lawrence Heights
# 7                                       Lawrence Manor
# 8                                         Not assigned
# 10                                    Islington Avenue
# 11                                               Rouge
# 12                                             Malvern
# 14                                     Don Mills North
# 15                                    Woodbine Gardens
# 16                                       Parkview Hill
# 17                                             Ryerson
# 18                                     Garden District
# 19                                           Glencairn
# 22                                          Cloverdale
# 23                                           Islington
# 24                                        Martin Grove
# 25                                    Princess Gardens
# 26                                     West Deane Park
# 27                                      Highland Creek
# 28                                          Rouge Hill
# 29                                          Port Union
# 31                                     Flemingdon Park
# 32                                     Don Mills South
# 33                                    Woodbine Heights
# 34                                      St. James Town
# 35                                  Humewood-Cedarvale
# 38                                   Bloordale Gardens
# ..                                                 ...
# 235                                        Thistletown
# 236                                    L'Amoreaux West
# 239                                           Rosedale
# 240                    Stn A PO Boxes 25 The Esplanade
# 243                                          Alderwood
# 244                                        Long Branch
# 245                                          Northwest
# 246                                        Upper Rouge
# 249                                        Cabbagetown
# 250                                     St. James Town
# 251                               First Canadian Place
# 252                                   Underground city
# 255                                       The Kingsway
# 256                                    Montgomery Road
# 257                                     Old Mill North
# 262                               Church and Wellesley
# 265  Business Reply Mail Processing Centre 969 Eastern
# 266                                         Humber Bay
# 267                                   King's Mill Park
# 268                           Kingsway Park South East
# 269                                          Mimico NE
# 270                                     Old Mill South
# 271                                 The Queensway East
# 272                              Royal York South East
# 273                                           Sunnylea
# 282                           Kingsway Park South West
# 283                                          Mimico NW
# 284                                 The Queensway West
# 285                              Royal York South West
# 286                                     South of Bloor
#
# [211 rows x 3 columns]

# %% [markdown]
# ### Observe the shape of the updated dataframe

# %%
df_del_na.shape
# Out:
# (211, 3)

# %% [markdown]
# ### Confirm that all 'Not assigned' Boroughs were removed

# %%
#check to see if there are any 'Not assigned' Neighborhoods
df_del_na[df_del_na.Neighbourhood == 'Not assigned']
# Out:
#   Postcode       Borough Neighbourhood
# 8      M7A  Queen's Park  Not assigned

# %% [markdown]
# ### Set Neighborhood from 'Not assigned' to "Queen's Park" (and view the results)

# %%
#set Neighborhood from 'Not assigned' to "Queen's Park"
df_del_na.loc[df_del_na['Neighbourhood'] == "Not assigned", 'Neighbourhood'] = "Queen's Park"
df_del_na
# Out:
#     Postcode           Borough  \
# 2        M3A        North York
# 3        M4A        North York
# 4        M5A  Downtown Toronto
# 5        M5A  Downtown Toronto
# 6        M6A        North York
# 7        M6A        North York
# 8        M7A      Queen's Park
# 10       M9A         Etobicoke
# 11       M1B       Scarborough
# 12       M1B       Scarborough
# 14       M3B        North York
# 15       M4B         East York
# 16       M4B         East York
# 17       M5B  Downtown Toronto
# 18       M5B  Downtown Toronto
# 19       M6B        North York
# 22       M9B         Etobicoke
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M1C       Scarborough
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# 31       M3C        North York
# 32       M3C        North York
# 33       M4C         East York
# 34       M5C  Downtown Toronto
# 35       M6C              York
# 38       M9C         Etobicoke
# ..       ...               ...
# 235      M9V         Etobicoke
# 236      M1W       Scarborough
# 239      M4W  Downtown Toronto
# 240      M5W  Downtown Toronto
# 243      M8W         Etobicoke
# 244      M8W         Etobicoke
# 245      M9W         Etobicoke
# 246      M1X       Scarborough
# 249      M4X  Downtown Toronto
# 250      M4X  Downtown Toronto
# 251      M5X  Downtown Toronto
# 252      M5X  Downtown Toronto
# 255      M8X         Etobicoke
# 256      M8X         Etobicoke
# 257      M8X         Etobicoke
# 262      M4Y  Downtown Toronto
# 265      M7Y      East Toronto
# 266      M8Y         Etobicoke
# 267      M8Y         Etobicoke
# 268      M8Y         Etobicoke
# 269      M8Y         Etobicoke
# 270      M8Y         Etobicoke
# 271      M8Y         Etobicoke
# 272      M8Y         Etobicoke
# 273      M8Y         Etobicoke
# 282      M8Z         Etobicoke
# 283      M8Z         Etobicoke
# 284      M8Z         Etobicoke
# 285      M8Z         Etobicoke
# 286      M8Z         Etobicoke
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                                         Harbourfront
# 5                                          Regent Park
# 6                                     Lawrence Heights
# 7                                       Lawrence Manor
# 8                                         Queen's Park
# 10                                    Islington Avenue
# 11                                               Rouge
# 12                                             Malvern
# 14                                     Don Mills North
# 15                                    Woodbine Gardens
# 16                                       Parkview Hill
# 17                                             Ryerson
# 18                                     Garden District
# 19                                           Glencairn
# 22                                          Cloverdale
# 23                                           Islington
# 24                                        Martin Grove
# 25                                    Princess Gardens
# 26                                     West Deane Park
# 27                                      Highland Creek
# 28                                          Rouge Hill
# 29                                          Port Union
# 31                                     Flemingdon Park
# 32                                     Don Mills South
# 33                                    Woodbine Heights
# 34                                      St. James Town
# 35                                  Humewood-Cedarvale
# 38                                   Bloordale Gardens
# ..                                                 ...
# 235                                        Thistletown
# 236                                    L'Amoreaux West
# 239                                           Rosedale
# 240                    Stn A PO Boxes 25 The Esplanade
# 243                                          Alderwood
# 244                                        Long Branch
# 245                                          Northwest
# 246                                        Upper Rouge
# 249                                        Cabbagetown
# 250                                     St. James Town
# 251                               First Canadian Place
# 252                                   Underground city
# 255                                       The Kingsway
# 256                                    Montgomery Road
# 257                                     Old Mill North
# 262                               Church and Wellesley
# 265  Business Reply Mail Processing Centre 969 Eastern
# 266                                         Humber Bay
# 267                                   King's Mill Park
# 268                           Kingsway Park South East
# 269                                          Mimico NE
# 270                                     Old Mill South
# 271                                 The Queensway East
# 272                              Royal York South East
# 273                                           Sunnylea
# 282                           Kingsway Park South West
# 283                                          Mimico NW
# 284                                 The Queensway West
# 285                              Royal York South West
# 286                                     South of Bloor
#
# [211 rows x 3 columns]

# %%
#check to verify 'Queen's Park'  Neighbourhood exists
df_del_na[df_del_na.Neighbourhood == "Queen's Park"]
# Out:
#   Postcode       Borough Neighbourhood
# 8      M7A  Queen's Park  Queen's Park

# %% [markdown]
# ### Rename column name from 'Neighbourhood' to 'Neighborhood'

# %%
df_del_na.rename(columns={'Postcode': 'PostalCode', 'Neighbourhood': 'Neighborhood'}, inplace=True)
df_del_na.head()
# Out:
#   PostalCode           Borough      Neighborhood
# 2        M3A        North York         Parkwoods
# 3        M4A        North York  Victoria Village
# 4        M5A  Downtown Toronto      Harbourfront
# 5        M5A  Downtown Toronto       Regent Park
# 6        M6A        North York  Lawrence Heights

# %% [markdown]
# ### View the groupby table

# %%
df_del_na_grouped = df_del_na.groupby(['PostalCode', 'Borough', 'Neighborhood']).count()
df_del_na_grouped
# Out:
# Empty DataFrame
# Columns: []
# Index: [(M1B, Scarborough, Malvern), (M1B, Scarborough, Rouge), (M1C, Scarborough, Highland Creek), (M1C, Scarborough, Port Union), (M1C, Scarborough, Rouge Hill), (M1E, Scarborough, Guildwood), (M1E, Scarborough, Morningside), (M1E, Scarborough, West Hill), (M1G, Scarborough, Woburn), (M1H, Scarborough, Cedarbrae), (M1J, Scarborough, Scarborough Village), (M1K, Scarborough, East Birchmount Park), (M1K, Scarborough, Ionview), (M1K, Scarborough, Kennedy Park), (M1L, Scarborough, Clairlea), (M1L, Scarborough, Golden Mile), (M1L, Scarborough, Oakridge), (M1M, Scarborough, Cliffcrest), (M1M, Scarborough, Cliffside), (M1M, Scarborough, Scarborough Village West), (M1N, Scarborough, Birch Cliff), (M1N, Scarborough, Cliffside West), (M1P, Scarborough, Dorset Park), (M1P, Scarborough, Scarborough Town Centre), (M1P, Scarborough, Wexford Heights), (M1R, Scarborough, Maryvale), (M1R, Scarborough, Wexford), (M1S, Scarborough, Agincourt), (M1T, Scarborough, Clarks Corners), (M1T, Scarborough, Sullivan), (M1T, Scarborough, Tam O'Shanter), (M1V, Scarborough, Agincourt North), (M1V, Scarborough, L'Amoreaux East), (M1V, Scarborough, Milliken), (M1V, Scarborough, Steeles East), (M1W, Scarborough, L'Amoreaux West), (M1X, Scarborough, Upper Rouge), (M2H, North York, Hillcrest Village), (M2J, North York, Fairview), (M2J, North York, Henry Farm), (M2J, North York, Oriole), (M2K, North York, Bayview Village), (M2L, North York, Silver Hills), (M2L, North York, York Mills), (M2M, North York, Newtonbrook), (M2M, North York, Willowdale), (M2N, North York, Willowdale South), (M2P, North York, York Mills West), (M2R, North York, Willowdale West), (M3A, North York, Parkwoods), (M3B, North York, Don Mills North), (M3C, North York, Don Mills South), (M3C, North York, Flemingdon Park), (M3H, North York, Bathurst Manor), (M3H, North York, Downsview North), (M3H, North York, Wilson Heights), (M3J, North York, Northwood Park), (M3J, North York, York University), (M3K, North York, CFB Toronto), (M3K, North York, Downsview East), (M3L, North York, Downsview West), (M3M, North York, Downsview Central), (M3N, North York, Downsview Northwest), (M4A, North York, Victoria Village), (M4B, East York, Parkview Hill), (M4B, East York, Woodbine Gardens), (M4C, East York, Woodbine Heights), (M4E, East Toronto, The Beaches), (M4G, East York, Leaside), (M4H, East York, Thorncliffe Park), (M4J, East York, East Toronto), (M4K, East Toronto, Riverdale), (M4K, East Toronto, The Danforth West), (M4L, East Toronto, India Bazaar), (M4L, East Toronto, The Beaches West), (M4M, East Toronto, Studio District), (M4N, Central Toronto, Lawrence Park), (M4P, Central Toronto, Davisville North), (M4R, Central Toronto, North Toronto West), (M4S, Central Toronto, Davisville), (M4T, Central Toronto, Moore Park), (M4T, Central Toronto, Summerhill East), (M4V, Central Toronto, Deer Park), (M4V, Central Toronto, Forest Hill SE), (M4V, Central Toronto, Rathnelly), (M4V, Central Toronto, South Hill), (M4V, Central Toronto, Summerhill West), (M4W, Downtown Toronto, Rosedale), (M4X, Downtown Toronto, Cabbagetown), (M4X, Downtown Toronto, St. James Town), (M4Y, Downtown Toronto, Church and Wellesley), (M5A, Downtown Toronto, Harbourfront), (M5A, Downtown Toronto, Regent Park), (M5B, Downtown Toronto, Garden District), (M5B, Downtown Toronto, Ryerson), (M5C, Downtown Toronto, St. James Town), (M5E, Downtown Toronto, Berczy Park), (M5G, Downtown Toronto, Central Bay Street), (M5H, Downtown Toronto, Adelaide), (M5H, Downtown Toronto, King), ...]
#
# [211 rows x 0 columns]

# %% [markdown]
# ### Flatten the table (for the rows in the Neighborhood columns)

# %%
#flatten groupby results by setting Neighborhood to list per row
df_del_na_grouped_flat = df_del_na.groupby(['PostalCode', 'Borough'])['Neighborhood'].apply(lambda group_series: group_series.tolist()).reset_index()
print(df_del_na_grouped_flat.head(10), '\n', '\n')
print(df_del_na_grouped_flat.tail(10))
# Out:
#   PostalCode      Borough                                       Neighborhood
# 0        M1B  Scarborough                                   [Rouge, Malvern]
# 1        M1C  Scarborough           [Highland Creek, Rouge Hill, Port Union]
# 2        M1E  Scarborough                [Guildwood, Morningside, West Hill]
# 3        M1G  Scarborough                                           [Woburn]
# 4        M1H  Scarborough                                        [Cedarbrae]
# 5        M1J  Scarborough                              [Scarborough Village]
# 6        M1K  Scarborough      [East Birchmount Park, Ionview, Kennedy Park]
# 7        M1L  Scarborough                  [Clairlea, Golden Mile, Oakridge]
# 8        M1M  Scarborough  [Cliffcrest, Cliffside, Scarborough Village West]
# 9        M1N  Scarborough                      [Birch Cliff, Cliffside West]
#
#
#     PostalCode     Borough                                       Neighborhood
# 93         M9A   Etobicoke                                 [Islington Avenue]
# 94         M9B   Etobicoke  [Cloverdale, Islington, Martin Grove, Princess...
# 95         M9C   Etobicoke  [Bloordale Gardens, Eringate, Markland Wood, O...
# 96         M9L  North York                                    [Humber Summit]
# 97         M9M  North York                                 [Emery, Humberlea]
# 98         M9N        York                                           [Weston]
# 99         M9P   Etobicoke                                        [Westmount]
# 100        M9R   Etobicoke  [Kingsview Village, Martin Grove Gardens, Rich...
# 101        M9V   Etobicoke  [Albion Gardens, Beaumond Heights, Humbergate,...
# 102        M9W   Etobicoke                                        [Northwest]

# %% [markdown]
# ### Evaluate the shape of the final table

# %%
df_del_na_grouped_flat.shape
# Out:
# (103, 3)
